# %% [markdown]
# ![MLU Logo](../data/MLU_Logo.png)

# %% [markdown]
# # <a name="0">Machine Learning Accelerator - Tabular Data - Lecture 3</a>
#
#
# ## AutoGluon
#
# In this notebook, we use __AutoGluon__ to predict the __Outcome Type__ field of our review dataset.
#
#
# [AutoGluon](https://auto.gluon.ai/stable/index.html) implements many of the best practices that we have discussed in this class, and more!  In particular, it sets itself apart from other AutoML solutions by having excellent automated feature engineering that can handle text data and missing values without any hand-coded solutions (See their [paper](https://arxiv.org/abs/2003.06505) for details).  It is too new to be in an existing Sagemaker kernel, so let's install it.
#
# 1. <a href="#1">Set up AutoGluon</a>
# 2. <a href="#2">Read the datasets</a>
# 3. <a href="#3">Train a classifier with AutoGluon</a>
# 4. <a href="#4">Model evaluation</a>
# 5. <a href="#5">Clean up model artifacts</a>
#
# __Austin Animal Center Dataset__:
#
# In this exercise, we are working with pet adoption data from __Austin Animal Center__. We have two datasets that cover intake and outcome of animals. Intake data is available from [here](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm) and outcome is from [here](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238).
#
# In order to work with a single table, we joined the intake and outcome tables using the "Animal ID" column and created a single __review.csv__ file. We also didn't consider animals with multiple entries to the facility to keep our dataset simple. If you want to see the original datasets and the merged data with multiple entries, they are available under data/review folder: Austin_Animal_Center_Intakes.csv, Austin_Animal_Center_Outcomes.csv and Austin_Animal_Center_Intakes_Outcomes.csv.
#
# __Dataset schema:__
# - __Pet ID__ - Unique ID of pet
# - __Outcome Type__ - State of pet at the time of recording the outcome (0 = not placed, 1 = placed). This is the field to predict.
# - __Sex upon Outcome__ - Sex of pet at outcome
# - __Name__ - Name of pet
# - __Found Location__ - Found location of pet before entered the center
# - __Intake Type__ - Circumstances bringing the pet to the center
# - __Intake Condition__ - Health condition of pet when entered the center
# - __Pet Type__ - Type of pet
# - __Sex upon Intake__ - Sex of pet when entered the center
# - __Breed__ - Breed of pet
# - __Color__ - Color of pet
# - __Age upon Intake Days__ - Age of pet when entered the center (days)
# - __Age upon Outcome Days__ - Age of pet at outcome (days))

# %% [markdown]
# ## 1. <a name="1">Set up AutoGluon</a>
# (<a href="#0">Go to top</a>)

# %%
! pip install -q -r ../requirements.txt

# %% [markdown]
# ## 2. <a name="2">Read the dataset</a>
# (<a href="#0">Go to top</a>)
#
# Let's read the dataset into a dataframe, using Pandas, and split the dataset into train and test sets (AutoGluon will handle the validation itself).

# %%
import pandas as pd

df = pd.read_csv('../data/review/review_dataset.csv')

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(df, test_size=0.1, shuffle=True, random_state=23)

# %% [markdown]
# ## 3. <a name="3">Train a classifier with AutoGluon</a>
# (<a href="#0">Go to top</a>)
#
# We can run AutoGluon with a short snippet. For fitting, we just call the __.fit()__ function. In this exercise, we used the data frame objects, but this tool also accepts the raw csv files as input. To use this tool with simple csv files, you can follow the code snippet below.
#
# ```python
# from autogluon.tabular import TabularDataset, TabularPredictor
#
# train_data = TabularDataset(file_path='path_to_dataset/train.csv')
# test_data = TabularDataset(file_path='path_to_dataset/test.csv')
#
# predictor = TabularPredictor(label='label_column').fit(train_data)
# test_predictions = predictor.predict(test_data)
# ```
#
# We have our separate __data frames__ for training and test data, so we work with them below. We grab the first 10000 data points for a quick demo. You can also pass the full dataset.

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

k = 10000 # grab less data for a quick demo
#k = train_data.shape[0] # grad the whole dataset

predictor = TabularPredictor(label='Outcome Type').fit(train_data.head(k))
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211103_161037/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20211103_161037/"
# AutoGluon Version:  0.3.0
# Train Data Rows:    10000
# Train Data Columns: 12
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [1.0, 0.0]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    13425.03 MB
# 	Train Data (Original)  Memory Usage: 6.86 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['Found Location']
# 			CountVectorizer fit with vocabulary size = 198
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Unused Original Features (Count: 1): ['Pet ID']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['Pet ID']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])          : 2 | ['Age upon Intake Days', 'Age upon Outcome Days']
# 		('object', [])       : 8 | ['Sex upon Outcome', 'Name', 'Intake Type', 'Intake Condition', 'Pet Type', ...]
# 		('object', ['text']) : 1 | ['Found Location']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :   8 | ['Sex upon Outcome', 'Name', 'Intake Type', 'Intake Condition', 'Pet Type', ...]
# 		('category', ['text_as_category'])  :   1 | ['Found Location']
# 		('int', [])                         :   2 | ['Age upon Intake Days', 'Age upon Outcome Days']
# 		('int', ['binned', 'text_special']) :  12 | ['Found Location.char_count', 'Found Location.word_count', 'Found Location.capital_ratio', 'Found Location.lower_ratio', 'Found Location.digit_ratio', ...]
# 		('int', ['text_ngram'])             : 199 | ['__nlp__.183', '__nlp__.183 and', '__nlp__.183 in', '__nlp__.183 in austin', '__nlp__.1st', ...]
# 	1.2s = Fit runtime
# 	11 features in original data used to generate 222 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.4 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.31s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 9000, Val Rows: 1000
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.615	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.615	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.85	 = Validation score   (accuracy)
# 	1.15s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM ...
# /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.849	 = Validation score   (accuracy)
# 	0.88s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.846	 = Validation score   (accuracy)
# 	2.51s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.848	 = Validation score   (accuracy)
# 	2.79s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.855	 = Validation score   (accuracy)
# 	3.65s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.841	 = Validation score   (accuracy)
# 	2.38s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.84	 = Validation score   (accuracy)
# 	2.6s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 2: early stopping
# 	0.823	 = Validation score   (accuracy)
# 	15.95s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.854	 = Validation score   (accuracy)
# 	1.21s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	0.832	 = Validation score   (accuracy)
# 	38.22s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.847	 = Validation score   (accuracy)
# 	1.51s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.87	 = Validation score   (accuracy)
# 	0.9s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 80.24s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211103_161037/")

# %% [markdown]
# We can also summarize what happened during fit.

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2      0.870       1.270723  57.796272                0.002387           0.901306            2       True         14
# 1              CatBoost      0.855       0.032627   3.649699                0.032627           3.649699            1       True          7
# 2               XGBoost      0.854       0.022961   1.210801                0.022961           1.210801            1       True         11
# 3            LightGBMXT      0.850       0.025665   1.146575                0.025665           1.146575            1       True          3
# 4              LightGBM      0.849       0.028768   0.883064                0.028768           0.883064            1       True          4
# 5      RandomForestEntr      0.848       0.214478   2.786693                0.214478           2.786693            1       True          6
# 6         LightGBMLarge      0.847       0.027167   1.505515                0.027167           1.505515            1       True         13
# 7      RandomForestGini      0.846       0.213100   2.514673                0.213100           2.514673            1       True          5
# 8        ExtraTreesGini      0.841       0.213823   2.379914                0.213823           2.379914            1       True          8
# 9        ExtraTreesEntr      0.840       0.214098   2.597267                0.214098           2.597267            1       True          9
# 10       NeuralNetMXNet      0.832       0.275649  38.220765                0.275649          38.220765            1       True         12
# 11      NeuralNetFastAI      0.823       0.116662  15.953786                0.116662          15.953786            1       True         10
# 12       KNeighborsDist      0.615       0.105733   0.019301                0.105733           0.019301            1       True          2
# 13       KNeighborsUnif      0.615       0.107929   0.023860                0.107929           0.023860            1       True          1
# Number of models trained: 14
# Types of models trained:
# {'XGBoostModel', 'WeightedEnsembleModel', 'LGBModel', 'RFModel', 'TabularNeuralNetModel', 'XTModel', 'NNFastAiTabularModel', 'CatBoostModel', 'KNNModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])                    :   8 | ['Sex upon Outcome', 'Name', 'Intake Type', 'Intake Condition', 'Pet Type', ...]
# ('category', ['text_as_category'])  :   1 | ['Found Location']
# ('int', [])                         :   2 | ['Age upon Intake Days', 'Age upon Outcome Days']
# ('int', ['binned', 'text_special']) :  12 | ['Found Location.char_count', 'Found Location.word_count', 'Found Location.capital_ratio', 'Found Location.lower_ratio', 'Found Location.digit_ratio', ...]
# ('int', ['text_ngram'])             : 199 | ['__nlp__.183', '__nlp__.183 and', '__nlp__.183 in', '__nlp__.183 in austin', '__nlp__.1st', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20211103_161037/SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif': 'KNNModel',
#   'KNeighborsDist': 'KNNModel',
#   'LightGBMXT': 'LGBModel',
#   'LightGBM': 'LGBModel',
#   'RandomForestGini': 'RFModel',
#   'RandomForestEntr': 'RFModel',
#   'CatBoost': 'CatBoostModel',
#   'ExtraTreesGini': 'XTModel',
#   'ExtraTreesEntr': 'XTModel',
#   'NeuralNetFastAI': 'NNFastAiTabularModel',
#   'XGBoost': 'XGBoostModel',
#   'NeuralNetMXNet': 'TabularNeuralNetModel',
#   'LightGBMLarge': 'LGBModel',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif': 0.615,
#   'KNeighborsDist': 0.615,
#   'LightGBMXT': 0.85,
#   'LightGBM': 0.849,
#   'RandomForestGini': 0.846,
#   'RandomForestEntr': 0.848,
#   'CatBoost': 0.855,
#   'ExtraTreesGini': 0.841,
#   'ExtraTreesEntr': 0.84,
#   'NeuralNetFastAI': 0.823,
#   'XGBoost': 0.854,
#   'NeuralNetMXNet': 0.832,
#   'LightGBMLarge': 0.847,
#   'WeightedEnsemble_L2': 0.87},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif': 'AutogluonModels/ag-20211103_161037/models/KNeighborsUnif/',
#   'KNeighborsDist': 'AutogluonModels/ag-20211103_161037/models/KNeighborsDist/',
#   'LightGBMXT': 'AutogluonModels/ag-20211103_161037/models/LightGBMXT/',
#   'LightGBM': 'AutogluonModels/ag-20211103_161037/models/LightGBM/',
#   'RandomForestGini': 'AutogluonModels/ag-20211103_161037/models/RandomForestGini/',
#   'RandomForestEntr': 'AutogluonModels/ag-20211103_161037/models/RandomForestEntr/',
#   'CatBoost': 'AutogluonModels/ag-20211103_161037/models/CatBoost/',
#   'ExtraTreesGini': 'AutogluonModels/ag-20211103_161037/models/ExtraTreesGini/',
#   'ExtraTreesEntr': 'AutogluonModels/ag-20211103_161037/models/ExtraTreesEntr/',
#   'NeuralNetFastAI': 'AutogluonModels/ag-20211103_161037/models/NeuralNetFastAI/',
#   'XGBoost': 'AutogluonModels/ag-20211103_161037/models/XGBoost/',
#   'NeuralNetMXNet': 'AutogluonModels/ag-20211103_161037/models/NeuralNetMXNet/',
#   'LightGBMLarge': 'AutogluonModels/ag-20211103_161037/models/LightGBMLarge/',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20211103_161037/models/WeightedEnsemble_L2/'},
#  'model_fit_times': {'KNeighborsUnif': 0.023859500885009766,
#   'KNeighborsDist': 0.01930069923400879,
#   'LightGBMXT': 1.1465747356414795,
#   'LightGBM': 0.883063554763794,
#   'RandomForestGini': 2.5146729946136475,
#   'RandomForestEntr': 2.7866928577423096,
#   'CatBoost': 3.6496994495391846,
#   'ExtraTreesGini': 2.379913806915283,
#   'ExtraTreesEntr': 2.5972671508789062,
#   'NeuralNetFastAI': 15.95378589630127,
#   'XGBoost': 1.2108006477355957,
#   'NeuralNetMXNet': 38.220765352249146,
#   'LightGBMLarge': 1.5055153369903564,
#   'WeightedEnsemble_L2': 0.9013059139251709},
#  'model_pred_times': {'KNeighborsUnif': 0.10792922973632812,
#   'KNeighborsDist': 0.10573267936706543,
#   'LightGBMXT': 0.025664567947387695,
#   'LightGBM': 0.028768301010131836,
#   'RandomForestGini': 0.21309995651245117,
#   'RandomForestEntr': 0.2144780158996582,
#   'CatBoost': 0.03262734413146973,
#   'ExtraTreesGini': 0.2138233184814453,
#   'ExtraTreesEntr': 0.21409845352172852,
#   'NeuralNetFastAI': 0.11666202545166016,
#   'XGBoost': 0.02296137809753418,
#   'NeuralNetMXNet': 0.2756485939025879,
#   'LightGBMLarge': 0.02716660499572754,
#   'WeightedEnsemble_L2': 0.002386808395385742},
#  'num_bag_folds': 0,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif': {'weights': 'uniform', 'n_jobs': -1},
#   'KNeighborsDist': {'weights': 'distance', 'n_jobs': -1},
#   'LightGBMXT': {'num_boost_round': 10000,
#    'num_threads': -1,
#    'learning_rate': 0.05,
#    'objective': 'binary',
#    'verbose': -1,
#    'boosting_type': 'gbdt',
#    'two_round': True,
#    'extra_trees': True},
#   'LightGBM': {'num_boost_round': 10000,
#    'num_threads': -1,
#    'learning_rate': 0.05,
#    'objective': 'binary',
#    'verbose': -1,
#    'boosting_type': 'gbdt',
#    'two_round': True},
#   'RandomForestGini': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'gini'},
#   'RandomForestEntr': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'entropy'},
#   'CatBoost': {'iterations': 10000,
#    'learning_rate': 0.05,
#    'random_seed': 0,
#    'allow_writing_files': False,
#    'eval_metric': 'Accuracy'},
#   'ExtraTreesGini': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'gini'},
#   'ExtraTreesEntr': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'entropy'},
#   'NeuralNetFastAI': {'layers': None,
#    'emb_drop': 0.1,
#    'ps': 0.1,
#    'bs': 256,
#    'lr': 0.01,
#    'epochs': 30,
#    'early.stopping.min_delta': 0.0001,
#    'early.stopping.patience': 20,
#    'smoothing': 0.0},
#   'XGBoost': {'n_estimators': 10000,
#    'learning_rate': 0.1,
#    'n_jobs': 4,
#    'proc.max_category_levels': 100,
#    'objective': 'binary:logistic',
#    'booster': 'gbtree',
#    'use_label_encoder': False},
#   'NeuralNetMXNet': {'num_epochs': 500,
#    'epochs_wo_improve': 20,
#    'seed_value': None,
#    'proc.embed_min_categories': 4,
#    'proc.impute_strategy': 'median',
#    'proc.max_category_levels': 100,
#    'proc.skew_threshold': 0.99,
#    'network_type': 'widedeep',
#    'layers': None,
#    'numeric_embed_dim': None,
#    'activation': 'relu',
#    'max_layer_width': 2056,
#    'embedding_size_factor': 1.0,
#    'embed_exponent': 0.56,
#    'max_embedding_dim': 100,
#    'y_range': None,
#    'y_range_extend': 0.05,
#    'use_batchnorm': True,
#    'dropout_prob': 0.1,
#    'batch_size': 512,
#    'loss_function': None,
#    'optimizer': 'adam',
#    'learning_rate': 0.0003,
#    'weight_decay': 1e-06,
#    'clip_gradient': 100.0,
#    'momentum': 0.9,
#    'lr_scheduler': None,
#    'base_lr': 3e-05,
#    'target_lr': 1.0,
#    'lr_decay': 0.1,
#    'warmup_epochs': 10,
#    'use_ngram_features': False},
#   'LightGBMLarge': {'num_boost_round': 10000,
#    'num_threads': -1,
#    'learning_rate': 0.03,
#    'objective': 'binary',
#    'verbose': -1,
#    'boosting_type': 'gbdt',
#    'two_round': True,
#    'num_leaves': 128,
#    'feature_fraction': 0.9,
#    'min_data_in_leaf': 5},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                   model  score_val  pred_time_val   fit_time  \
#  0   WeightedEnsemble_L2      0.870       1.270723  57.796272
#  1              CatBoost      0.855       0.032627   3.649699
#  2               XGBoost      0.854       0.022961   1.210801
#  3            LightGBMXT      0.850       0.025665   1.146575
#  4              LightGBM      0.849       0.028768   0.883064
#  5      RandomForestEntr      0.848       0.214478   2.786693
#  6         LightGBMLarge      0.847       0.027167   1.505515
#  7      RandomForestGini      0.846       0.213100   2.514673
#  8        ExtraTreesGini      0.841       0.213823   2.379914
#  9        ExtraTreesEntr      0.840       0.214098   2.597267
#  10       NeuralNetMXNet      0.832       0.275649  38.220765
#  11      NeuralNetFastAI      0.823       0.116662  15.953786
#  12       KNeighborsDist      0.615       0.105733   0.019301
#  13       KNeighborsUnif      0.615       0.107929   0.023860
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.002387           0.901306            2       True
#  1                 0.032627           3.649699            1       True
#  2                 0.022961           1.210801            1       True
#  3                 0.025665           1.146575            1       True
#  4                 0.028768           0.883064            1       True
#  5                 0.214478           2.786693            1       True
#  6                 0.027167           1.505515            1       True
#  7                 0.213100           2.514673            1       True
#  8                 0.213823           2.379914            1       True
#  9                 0.214098           2.597267            1       True
#  10                0.275649          38.220765            1       True
#  11                0.116662          15.953786            1       True
#  12                0.105733           0.019301            1       True
#  13                0.107929           0.023860            1       True
#
#      fit_order
#  0          14
#  1           7
#  2          11
#  3           3
#  4           4
#  5           6
#  6          13
#  7           5
#  8           8
#  9           9
#  10         12
#  11         10
#  12          2
#  13          1  }

# %% [markdown]
# ## 4. <a name="4">Model evaluation</a>
# (<a href="#0">Go to top</a>)
#
# Next, we load a separate test data to demonstrate how to make predictions on new examples at inference time.

# %%
# First predictions
y_pred = predictor.predict(test_data.head(k))

# Then, evaluations
predictor.evaluate_predictions(y_true=test_data['Outcome Type'],
                               y_pred=y_pred,
                               auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.8587286626871924
# Evaluations on test data:
# {
#     "accuracy": 0.8587286626871924,
#     "balanced_accuracy": 0.8456890403289204,
#     "mcc": 0.7151399160908474,
#     "f1": 0.8833145921633077,
#     "precision": 0.8310546875,
#     "recall": 0.9425881484216356
# }
# {'accuracy': 0.8587286626871924,
#  'balanced_accuracy': 0.8456890403289204,
#  'mcc': 0.7151399160908474,
#  'f1': 0.8833145921633077,
#  'precision': 0.8310546875,
#  'recall': 0.9425881484216356}

# %% [markdown]
# We can see the performance of each individual trained model on the test data:

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0   WeightedEnsemble_L2    0.858729      0.870        5.580307       1.270723
# 1      RandomForestEntr    0.855692      0.848        0.384348       0.214478
# 2      RandomForestGini    0.854226      0.846        0.388249       0.213100
# 3              CatBoost    0.854016      0.855        0.049642       0.032627
# 4              LightGBM    0.850979      0.849        0.099026       0.028768
# 5               XGBoost    0.849722      0.854        0.123578       0.022961
# 6         LightGBMLarge    0.845115      0.847        0.086906       0.027167
# 7            LightGBMXT    0.843439      0.850        0.073735       0.025665
# 8        ExtraTreesEntr    0.839460      0.840        0.502413       0.214098
# 9        ExtraTreesGini    0.837679      0.841        0.448305       0.213823
# 10       NeuralNetMXNet    0.833700      0.832        3.414086       0.275649
# 11      NeuralNetFastAI    0.823228      0.823        0.419598       0.116662
# 12       KNeighborsDist    0.613048      0.615        0.210449       0.105733
# 13       KNeighborsUnif    0.612630      0.615        0.105381       0.107929
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   57.796272                 0.010019                0.002387
# 1    2.786693                 0.384348                0.214478
# 2    2.514673                 0.388249                0.213100
# 3    3.649699                 0.049642                0.032627
# 4    0.883064                 0.099026                0.028768
# 5    1.210801                 0.123578                0.022961
# 6    1.505515                 0.086906                0.027167
# 7    1.146575                 0.073735                0.025665
# 8    2.597267                 0.502413                0.214098
# 9    2.379914                 0.448305                0.213823
# 10  38.220765                 3.414086                0.275649
# 11  15.953786                 0.419598                0.116662
# 12   0.019301                 0.210449                0.105733
# 13   0.023860                 0.105381                0.107929
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            0.901306            2       True         14
# 1            2.786693            1       True          6
# 2            2.514673            1       True          5
# 3            3.649699            1       True          7
# 4            0.883064            1       True          4
# 5            1.210801            1       True         11
# 6            1.505515            1       True         13
# 7            1.146575            1       True          3
# 8            2.597267            1       True          9
# 9            2.379914            1       True          8
# 10          38.220765            1       True         12
# 11          15.953786            1       True         10
# 12           0.019301            1       True          2
# 13           0.023860            1       True          1

# %% [markdown]
# ## 5. <a name="5">Clean up model artifacts</a>
# (<a href="#0">Go to top</a>)

# %%
# !rm -r AutogluonModels
